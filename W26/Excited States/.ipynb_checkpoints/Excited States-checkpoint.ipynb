# %% [raw]
# H2+ Potential Energy Curves for Ground and Excited States

# %%
#makes a file containing all the energy for each bond length

# h2plus_fci_pec.py
import psi4
import numpy as np
import csv

#choose basis (small to large):
#cc-pVDZ, cc-pVTZ, cc-pVQZ, cc-pV5Z,
#aug-cc-pVDZ, aug-cc-pVTZ, aug-cc-pVQZ, aug-cc-pV5Z"

basis = "aug-cc-pV5Z"

roots = 5                                        #number of potential energy curves to calculate, including ground state

r_min, r_max, n_points = 0.2, 5.0, 1000          #max and min bond length, number of points
csv_out = "h2plus_fci_pec.csv"                   #name csv output file
psi4_out = "h2plus_fci_scan.out"                 #name psi4 output file

psi4.set_output_file(psi4_out, False)            #(Names output file, overrides existing files)
psi4.set_memory("4 GB")                          #How much ram psi4 is allowed to use
psi4.set_num_threads(4)                          #number of threads to use

#set up psi4
psi4.core.clean_options()        #resets options
psi4.set_options({
    "basis": basis,              #set basis
    "reference": "rohf",         #Restricted Open-Shell Hartree-Fock, needed for open shell system, can also use uhf
    "guess": "sad",              #initial guess
    "scf_type": "pk",            #compute exact integrals
    "e_convergence": 1e-10,      #convergence limits
    "d_convergence": 1e-10,
    "maxiter": 200,              #max iterations
    "num_roots": roots,
})

#create an array of points
bond_lengths = np.linspace(r_min, r_max, n_points)

#run scan for each root at a set R
def run_h2plus_fci(R, roots, basis):        
    #create molecule
    mol = psi4.geometry(f"""
        1 2                               #charge, multiplicity
        H                                 #first hydrogen at (0,0,0)
        H 1 {R}                           #second hydrogen at distance R from hydrogen #1
        units angstrom                    #units of R in angstroms
        symmetry c1                       #turns off symmetry
        """)
    
    psi4.core.clean()                     #removes scratch files, clears data
    psi4.energy("fci", molecule=mol)      #calculate energy using Full Configuration Interaction for my mol
    vars_dict = psi4.core.variables()     #creates a dictionary with psi4 variables

    energies = []                         #create an empty list for energies

    #add each calculated root to the energies list
    for n in range(roots):
        energies.append(vars_dict[f"CI ROOT {n} TOTAL ENERGY"])

    #returns a list of the energies of each root at the n values
    return energies

#empty list for rows
rows = []

#run psi4 for each R
for R in bond_lengths:
    try:
        energies = run_h2plus_fci(R, roots, basis)   #runs function for R
        rows.append([R] + energies)                  #adds ([R], [energies]) to my list of rows
        #print(f"R = {R:.3f} done")                  #print when done
    except Exception as err:
        print(f"R = {R:.3f} failed: {err}")
        #leaves a gap
        rows.append([R] + [np.nan] * roots)
    finally:
        psi4.core.clean()
        psi4.core.clean_options()

with open(csv_out, "w", newline="") as f:
    writer = csv.writer(f)
    headers = ["R_angstrom"]
    for i in range (roots): 
        headers.append(f"E_root{i}")
    writer.writerow(headers)
    writer.writerows(rows)

print("Done. Wrote h2plus_fci_pec.csv")
# Out:
#   Memory set to   1.863 GiB by Python driver.
#   Threads set to 4 by Python driver.
# R = 0.200 done
# R = 0.210 done
# R = 0.219 done
# R = 0.229 done
# R = 0.238 done
# R = 0.248 done
# R = 0.258 done
# R = 0.267 done
# R = 0.277 done
# R = 0.287 done
# R = 0.296 done
# R = 0.306 done
# R = 0.315 done
# R = 0.325 done
# R = 0.335 done
# R = 0.344 done
# R = 0.354 done
# R = 0.364 done
# R = 0.373 done
# R = 0.383 done
# R = 0.392 done
# R = 0.402 done
# R = 0.412 done
# R = 0.421 done
# R = 0.431 done
# R = 0.440 done
# R = 0.450 done
# R = 0.460 done
# R = 0.469 done
# R = 0.479 done
# R = 0.489 done
# R = 0.498 done
# R = 0.508 done
# R = 0.517 done
# R = 0.527 done
# R = 0.537 done
# R = 0.546 done
# R = 0.556 done
# R = 0.566 done
# R = 0.575 done
# R = 0.585 done
# R = 0.594 done
# R = 0.604 done
# R = 0.614 done
# R = 0.623 done
# R = 0.633 done
# R = 0.642 done
# R = 0.652 done
# R = 0.662 done
# R = 0.671 done
# R = 0.681 done
# R = 0.691 done
# R = 0.700 done
# R = 0.710 done
# R = 0.719 done
# R = 0.729 done
# R = 0.739 done
# R = 0.748 done
# R = 0.758 done
# R = 0.768 done
# R = 0.777 done
# R = 0.787 done
# R = 0.796 done
# R = 0.806 done
# R = 0.816 done
# R = 0.825 done
# R = 0.835 done
# R = 0.844 done
# R = 0.854 done
# R = 0.864 done
# R = 0.873 done
# R = 0.883 done
# R = 0.893 done
# R = 0.902 done
# R = 0.912 done
# R = 0.921 done
# R = 0.931 done
# R = 0.941 done
# R = 0.950 done
# R = 0.960 done
# R = 0.970 done
# R = 0.979 done
# R = 0.989 done
# R = 0.998 done
# R = 1.008 done
# R = 1.018 done
# R = 1.027 done
# R = 1.037 done
# R = 1.046 done
# R = 1.056 done
# R = 1.066 done
# R = 1.075 done
# R = 1.085 done
# R = 1.095 done
# R = 1.104 done
# R = 1.114 done
# R = 1.123 done
# R = 1.133 done
# R = 1.143 done
# R = 1.152 done
# R = 1.162 done
# R = 1.172 done
# R = 1.181 done
# R = 1.191 done
# R = 1.200 done
# R = 1.210 done
# R = 1.220 done
# R = 1.229 done
# R = 1.239 done
# R = 1.248 done
# R = 1.258 done
# R = 1.268 done
# R = 1.277 done
# R = 1.287 done
# R = 1.297 done
# R = 1.306 done
# R = 1.316 done
# R = 1.325 done
# R = 1.335 done
# R = 1.345 done
# R = 1.354 done
# R = 1.364 done
# R = 1.374 done
# R = 1.383 done
# R = 1.393 done
# R = 1.402 done
# R = 1.412 done
# R = 1.422 done
# R = 1.431 done
# R = 1.441 done
# R = 1.451 done
# R = 1.460 done
# R = 1.470 done
# R = 1.479 done
# R = 1.489 done
# R = 1.499 done
# R = 1.508 done
# R = 1.518 done
# R = 1.527 done
# R = 1.537 done
# R = 1.547 done
# R = 1.556 done
# R = 1.566 done
# R = 1.576 done
# R = 1.585 done
# R = 1.595 done
# R = 1.604 done
# R = 1.614 done
# R = 1.624 done
# R = 1.633 done
# R = 1.643 done
# R = 1.653 done
# R = 1.662 done
# R = 1.672 done
# R = 1.681 done
# R = 1.691 done
# R = 1.701 done
# R = 1.710 done
# R = 1.720 done
# R = 1.729 done
# R = 1.739 done
# R = 1.749 done
# R = 1.758 done
# R = 1.768 done
# R = 1.778 done
# R = 1.787 done
# R = 1.797 done
# R = 1.806 done
# R = 1.816 done
# R = 1.826 done
# R = 1.835 done
# R = 1.845 done
# R = 1.855 done
# R = 1.864 done
# R = 1.874 done
# R = 1.883 done
# R = 1.893 done
# R = 1.903 done
# R = 1.912 done
# R = 1.922 done
# R = 1.931 done
# R = 1.941 done
# R = 1.951 done
# R = 1.960 done
# R = 1.970 done
# R = 1.980 done
# R = 1.989 done
# R = 1.999 done
# R = 2.008 done
# R = 2.018 done
# R = 2.028 done
# R = 2.037 done
# R = 2.047 done
# R = 2.057 done
# R = 2.066 done
# R = 2.076 done
# R = 2.085 done
# R = 2.095 done
# R = 2.105 done
# R = 2.114 done
# R = 2.124 done
# R = 2.133 done
# R = 2.143 done
# R = 2.153 done
# R = 2.162 done
# R = 2.172 done
# R = 2.182 done
# R = 2.191 done
# R = 2.201 done
# R = 2.210 done
# R = 2.220 done
# R = 2.230 done
# R = 2.239 done
# R = 2.249 done
# R = 2.259 done
# R = 2.268 done
# R = 2.278 done
# R = 2.287 done
# R = 2.297 done
# R = 2.307 done
# R = 2.316 done
# R = 2.326 done
# R = 2.335 done
# R = 2.345 done
# R = 2.355 done
# R = 2.364 done
# R = 2.374 done
# R = 2.384 done
# R = 2.393 done
# R = 2.403 done
# R = 2.412 done
# R = 2.422 done
# R = 2.432 done
# R = 2.441 done
# R = 2.451 done
# R = 2.461 done
# R = 2.470 done
# R = 2.480 done
# R = 2.489 done
# R = 2.499 done
# R = 2.509 done
# R = 2.518 done
# R = 2.528 done
# R = 2.537 done
# R = 2.547 done
# R = 2.557 done
# R = 2.566 done
# R = 2.576 done
# R = 2.586 done
# R = 2.595 done
# R = 2.605 done
# R = 2.614 done
# R = 2.624 done
# R = 2.634 done
# R = 2.643 done
# R = 2.653 done
# R = 2.663 done
# R = 2.672 done
# R = 2.682 done
# R = 2.691 done
# R = 2.701 done
# R = 2.711 done
# R = 2.720 done
# R = 2.730 done
# R = 2.739 done
# R = 2.749 done
# R = 2.759 done
# R = 2.768 done
# R = 2.778 done
# R = 2.788 done
# R = 2.797 done
# R = 2.807 done
# R = 2.816 done
# R = 2.826 done
# R = 2.836 done
# R = 2.845 done
# R = 2.855 done
# R = 2.865 done
# R = 2.874 done
# R = 2.884 done
# R = 2.893 done
# R = 2.903 done
# R = 2.913 done
# R = 2.922 done
# R = 2.932 done
# R = 2.941 done
# R = 2.951 done
# R = 2.961 done
# R = 2.970 done
# R = 2.980 done
# R = 2.990 done
# R = 2.999 done
# R = 3.009 done
# R = 3.018 done
# R = 3.028 done
# R = 3.038 done
# R = 3.047 done
# R = 3.057 done
# R = 3.067 done
# R = 3.076 done
# R = 3.086 done
# R = 3.095 done
# R = 3.105 done
# R = 3.115 done
# R = 3.124 done
# R = 3.134 done
# R = 3.143 done
# R = 3.153 done
# R = 3.163 done
# R = 3.172 done
# R = 3.182 done
# R = 3.192 done
# R = 3.201 done
# R = 3.211 done
# R = 3.220 done
# R = 3.230 done
# R = 3.240 done
# R = 3.249 done
# R = 3.259 done
# R = 3.269 done
# R = 3.278 done
# R = 3.288 done
# R = 3.297 done
# R = 3.307 done
# R = 3.317 done
# R = 3.326 done
# R = 3.336 done
# R = 3.345 done
# R = 3.355 done
# R = 3.365 done
# R = 3.374 done
# R = 3.384 done
# R = 3.394 done
# R = 3.403 done
# R = 3.413 done
# R = 3.422 done
# R = 3.432 done
# R = 3.442 done
# R = 3.451 done
# R = 3.461 done
# R = 3.471 done
# R = 3.480 done
# R = 3.490 done
# R = 3.499 done
# R = 3.509 done
# R = 3.519 done
# R = 3.528 done
# R = 3.538 done
# R = 3.547 done
# R = 3.557 done
# R = 3.567 done
# R = 3.576 done
# R = 3.586 done
# R = 3.596 done
# R = 3.605 done
# R = 3.615 done
# R = 3.624 done
# R = 3.634 done
# R = 3.644 done
# R = 3.653 done
# R = 3.663 done
# R = 3.673 done
# R = 3.682 done
# R = 3.692 done
# R = 3.701 done
# R = 3.711 done
# R = 3.721 done
# R = 3.730 done
# R = 3.740 done
# R = 3.749 done
# R = 3.759 done
# R = 3.769 done
# R = 3.778 done
# R = 3.788 done
# R = 3.798 done
# R = 3.807 done
# R = 3.817 done
# R = 3.826 done
# R = 3.836 done
# R = 3.846 done
# R = 3.855 done
# R = 3.865 done
# R = 3.875 done
# R = 3.884 done
# R = 3.894 done
# R = 3.903 done
# R = 3.913 done
# R = 3.923 done
# R = 3.932 done
# R = 3.942 done
# R = 3.952 done
# R = 3.961 done
# R = 3.971 done
# R = 3.980 done
# R = 3.990 done
# R = 4.000 done
# R = 4.009 done
# R = 4.019 done
# R = 4.028 done
# R = 4.038 done
# R = 4.048 done
# R = 4.057 done
# R = 4.067 done
# R = 4.077 done
# R = 4.086 done
# R = 4.096 done
# R = 4.105 done
# R = 4.115 done
# R = 4.125 done
# R = 4.134 done
# R = 4.144 done
# R = 4.154 done
# R = 4.163 done
# R = 4.173 done
# R = 4.182 done
# R = 4.192 done
# R = 4.202 done
# R = 4.211 done
# R = 4.221 done
# R = 4.230 done
# R = 4.240 done
# R = 4.250 done
# R = 4.259 done
# R = 4.269 done
# R = 4.279 done
# R = 4.288 done
# R = 4.298 done
# R = 4.307 done
# R = 4.317 done
# R = 4.327 done
# R = 4.336 done
# R = 4.346 done
# R = 4.356 done
# R = 4.365 done
# R = 4.375 done
# R = 4.384 done
# R = 4.394 done
# R = 4.404 done
# R = 4.413 done
# R = 4.423 done
# R = 4.432 done
# R = 4.442 done
# R = 4.452 done
# R = 4.461 done
# R = 4.471 done
# R = 4.481 done
# R = 4.490 done
# R = 4.500 done
# R = 4.509 done
# R = 4.519 done
# R = 4.529 done
# R = 4.538 done
# R = 4.548 done
# R = 4.558 done
# R = 4.567 done
# R = 4.577 done
# R = 4.586 done
# R = 4.596 done
# R = 4.606 done
# R = 4.615 done
# R = 4.625 done
# R = 4.634 done
# R = 4.644 done
# R = 4.654 done
# R = 4.663 done
# R = 4.673 done
# R = 4.683 done
# R = 4.692 done
# R = 4.702 done
# R = 4.711 done
# R = 4.721 done
# R = 4.731 done
# R = 4.740 done
# R = 4.750 done
# R = 4.760 done
# R = 4.769 done
# R = 4.779 done
# R = 4.788 done
# R = 4.798 done
# R = 4.808 done
# R = 4.817 done
# R = 4.827 done
# R = 4.836 done
# R = 4.846 done
# R = 4.856 done
# R = 4.865 done
# R = 4.875 done
# R = 4.885 done
# R = 4.894 done
# R = 4.904 done
# R = 4.913 done
# R = 4.923 done
# R = 4.933 done
# R = 4.942 done
# R = 4.952 done
# R = 4.962 done
# R = 4.971 done
# R = 4.981 done
# R = 4.990 done
# R = 5.000 done
# Done. Wrote h2plus_fci_pec.csv

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

filename = "h2plus_fci_pec.csv"


R = []

with open(filename, "r") as f:
    reader = csv.reader(f)
    header = next(reader)

    n_roots = len(header) - 1
    energies = [[] for _ in range(n_roots)]
    
    for row in reader:
        R.append(float(row[0]))

        for i in range(n_roots):
            try:
                val = float(row[i+1])
            except:
                val = np.nan
            energies[i].append(val)

R = np.array(R)
energies = [np.array(e) for e in energies]

plt.figure(figsize=(8,6))
for i, e in enumerate(energies):
    plt.plot(R, e, label=f"Root {i}")

plt.xlabel("Bond Length (Å)")
plt.ylabel("Energy (Hartree)")
plt.title("H2+ Potential Energy Curves (FCI)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import psi4
import numpy as np
import csv

psi4.set_memory("2 GB")
psi4.set_num_threads(4)
psi4.core.set_output_file("h2_fci_scan.out", False)

roots = 10

def run_h2_fci(R, nroots = roots, basis="aug-cc-pVQZ"):
    psi4.core.clean()
    psi4.core.clean_options()

    mol = psi4.geometry(f"""
    0 1
    H
    H 1 {R}
    units angstrom
    """)

    psi4.set_options({
        "basis": basis,
        "reference": "rhf",
        "guess": "sad",
        "scf_type": "pk",
        "freeze_core": False,
        "num_roots": nroots
    })

    psi4.energy("fci", molecule=mol)
    vars_dict = psi4.core.variables()

    energies = []
    for n in range(nroots):
        key = f"CI ROOT {n} TOTAL ENERGY"
        energies.append(vars_dict[key])

    return energies

bond_lengths = np.linspace(0.2, 5.0, 200)

rows = []
for R in bond_lengths:
    try:
        energies = run_h2_fci(R, roots, basis="aug-cc-pVQZ")
        rows.append([R] + energies)
        print(f"R = {R:.3f} done")
    except Exception as err:
        print(f"R = {R:.3f} failed: {err}")
        rows.append([R] + [np.nan] * roots)
    finally:
        psi4.core.clean()
        psi4.core.clean_options()

with open("h2_fci_pec.csv", "w", newline="") as f:
    writer = csv.writer(f)
    write = ["R_angstrom"]
    for i in range (0, roots):
        write.append(f"E_root_{i}")
    writer.writerow(write)
    writer.writerows(rows)

print("Done. Wrote h2_fci_pec.csv")
# Out:
#   Memory set to   1.863 GiB by Python driver.
#   Threads set to 4 by Python driver.
# R = 0.200 done
# R = 0.224 done
# R = 0.248 done
# R = 0.272 done
# R = 0.296 done
# R = 0.321 done
# R = 0.345 done
# R = 0.369 done
# R = 0.393 done
# R = 0.417 done
# R = 0.441 done
# R = 0.465 done
# R = 0.489 done
# R = 0.514 done
# R = 0.538 done
# R = 0.562 done
# R = 0.586 done
# R = 0.610 done
# R = 0.634 done
# R = 0.658 done
# R = 0.682 done
# R = 0.707 done
# R = 0.731 done
# R = 0.755 done
# R = 0.779 done
# R = 0.803 done
# R = 0.827 done
# R = 0.851 done
# R = 0.875 done
# R = 0.899 done
# R = 0.924 done
# R = 0.948 done
# R = 0.972 done
# R = 0.996 done
# R = 1.020 done
# R = 1.044 done
# R = 1.068 done
# R = 1.092 done
# R = 1.117 done
# R = 1.141 done
# R = 1.165 done
# R = 1.189 done
# R = 1.213 done
# R = 1.237 done
# R = 1.261 done
# R = 1.285 done
# R = 1.310 done
# R = 1.334 done
# R = 1.358 done
# R = 1.382 done
# R = 1.406 done
# R = 1.430 done
# R = 1.454 done
# R = 1.478 done
# R = 1.503 done
# R = 1.527 done
# R = 1.551 done
# R = 1.575 done
# R = 1.599 done
# R = 1.623 done
# R = 1.647 done
# R = 1.671 done
# R = 1.695 done
# R = 1.720 done
# R = 1.744 done
# R = 1.768 done
# R = 1.792 done
# R = 1.816 done
# R = 1.840 done
# R = 1.864 done
# R = 1.888 done
# R = 1.913 done
# R = 1.937 done
# R = 1.961 done
# R = 1.985 done
# R = 2.009 done
# R = 2.033 done
# R = 2.057 done
# R = 2.081 done
# R = 2.106 done
# R = 2.130 done
# R = 2.154 done
# R = 2.178 done
# R = 2.202 done
# R = 2.226 done
# R = 2.250 done
# R = 2.274 done
# R = 2.298 done
# R = 2.323 done
# R = 2.347 done
# R = 2.371 done
# R = 2.395 done
# R = 2.419 done
# R = 2.443 done
# R = 2.467 done
# R = 2.491 done
# R = 2.516 done
# R = 2.540 done
# R = 2.564 done
# R = 2.588 done
# R = 2.612 done
# R = 2.636 done
# R = 2.660 done
# R = 2.684 done
# R = 2.709 done
# R = 2.733 done
# R = 2.757 done
# R = 2.781 done
# R = 2.805 done
# R = 2.829 done
# R = 2.853 done
# R = 2.877 done
# R = 2.902 done
# R = 2.926 done
# R = 2.950 done
# R = 2.974 done
# R = 2.998 done
# R = 3.022 done
# R = 3.046 done
# R = 3.070 done
# R = 3.094 done
# R = 3.119 done
# R = 3.143 done
# R = 3.167 done
# R = 3.191 done
# R = 3.215 done
# R = 3.239 done
# R = 3.263 done
# R = 3.287 done
# R = 3.312 done
# R = 3.336 done
# R = 3.360 done
# R = 3.384 done
# R = 3.408 done
# R = 3.432 done
# R = 3.456 done
# R = 3.480 done
# R = 3.505 done
# R = 3.529 done
# R = 3.553 done
# R = 3.577 done
# R = 3.601 done
# R = 3.625 done
# R = 3.649 done
# R = 3.673 done
# R = 3.697 done
# R = 3.722 done
# R = 3.746 done
# R = 3.770 done
# R = 3.794 done
# R = 3.818 done
# R = 3.842 done
# R = 3.866 done
# R = 3.890 done
# R = 3.915 done
# R = 3.939 done
# R = 3.963 done
# R = 3.987 done
# R = 4.011 done
# R = 4.035 done
# R = 4.059 done
# R = 4.083 done
# R = 4.108 done
# R = 4.132 done
# R = 4.156 done
# R = 4.180 done
# R = 4.204 done
# R = 4.228 done
# R = 4.252 done
# R = 4.276 done
# R = 4.301 done
# R = 4.325 done
# R = 4.349 done
# R = 4.373 done
# R = 4.397 done
# R = 4.421 done
# R = 4.445 done
# R = 4.469 done
# R = 4.493 done
# R = 4.518 done
# R = 4.542 done
# R = 4.566 done
# R = 4.590 done
# R = 4.614 done
# R = 4.638 done
# R = 4.662 done
# R = 4.686 done
# R = 4.711 done
# R = 4.735 done
# R = 4.759 done
# R = 4.783 done
# R = 4.807 done
# R = 4.831 done
# R = 4.855 done
# R = 4.879 done
# R = 4.904 done
# R = 4.928 done
# R = 4.952 done
# R = 4.976 done
# R = 5.000 done
# Done. Wrote h2_fci_pec.csv

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv

filename = "h2_fci_pec.csv"

# Read data
R = []
energies = []

with open(filename, "r") as f:
    reader = csv.reader(f)
    header = next(reader)

    n_roots = len(header) - 1
    energies = [[] for _ in range(n_roots)]

    for row in reader:
        R.append(float(row[0]))

        for i in range(n_roots):
            try:
                val = float(row[i+1])
            except:
                val = np.nan
            energies[i].append(val)

R = np.array(R)
energies = [np.array(e) for e in energies]

# Plot
plt.figure(figsize=(8,6))

for i, e in enumerate(energies):
    plt.plot(R, e, label=f"Root {i}")

plt.xlabel("Bond Length (Å)")
plt.ylabel("Energy (Hartree)")
plt.title("H2 Potential Energy Curves (FCI)")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import psi4
import numpy as np
import csv

psi4.set_memory("2 GB")
psi4.set_num_threads(4)
psi4.core.set_output_file("h2_fci_spin_scan.out", False)

n_singlet_roots = 11
n_triplet_roots = 11
basis = "aug-cc-pVQZ"
bond_lengths = np.linspace(0.2, 5.0, 200)

def run_h2_fci(R, multiplicity, roots, basis=basis):
    psi4.core.clean()
    psi4.core.clean_options()

    mol = psi4.geometry(f"""
    0 {multiplicity}
    H
    H 1 {R}
    units angstrom
    """)

    reference = "rhf" if multiplicity == 1 else "rohf"

    psi4.set_options({
        "basis": basis,
        "reference": reference,
        "guess": "sad",
        "scf_type": "pk",
        "freeze_core": False,
        "num_roots": roots
    })

    psi4.energy("fci", molecule=mol)
    vars_dict = psi4.core.variables()

    energies = []
    for n in range(roots):
        key = f"CI ROOT {n} TOTAL ENERGY"
        energies.append(vars_dict[key])

    return energies

rows = []
for R in bond_lengths:
    singlet_energies = [np.nan] * n_singlet_roots
    triplet_energies = [np.nan] * n_triplet_roots

    try:
        singlet_energies = run_h2_fci(R, multiplicity=1, roots=n_singlet_roots, basis=basis)
        print(f"R = {R:.3f} singlet done")
    except Exception as err:
        print(f"R = {R:.3f} singlet failed: {err}")

    try:
        triplet_energies = run_h2_fci(R, multiplicity=3, roots=n_triplet_roots, basis=basis)
        print(f"R = {R:.3f} triplet done")
    except Exception as err:
        print(f"R = {R:.3f} triplet failed: {err}")

    row = [R] + singlet_energies + triplet_energies
    rows.append(row)

header = ["R_angstrom"]
header += [f"E_singlet_root_{i}" for i in range(n_singlet_roots)]
header += [f"E_triplet_root_{i}" for i in range(n_triplet_roots)]

with open("h2_fci_singlet_triplet.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerows(rows)

print("Done. Wrote h2_fci_singlet_triplet.csv")
# Out:
#   Memory set to   1.863 GiB by Python driver.
#   Threads set to 4 by Python driver.
# R = 0.200 singlet done
# R = 0.200 triplet done
# R = 0.224 singlet done
# R = 0.224 triplet done
# R = 0.248 singlet done
# R = 0.248 triplet done
# R = 0.272 singlet done
# R = 0.272 triplet done
# R = 0.296 singlet done
# R = 0.296 triplet done
# R = 0.321 singlet done
# R = 0.321 triplet done
# R = 0.345 singlet done
# R = 0.345 triplet done
# R = 0.369 singlet done
# R = 0.369 triplet done
# R = 0.393 singlet done
# R = 0.393 triplet done
# R = 0.417 singlet done
# R = 0.417 triplet done
# R = 0.441 singlet done
# R = 0.441 triplet done
# R = 0.465 singlet done
# R = 0.465 triplet done
# R = 0.489 singlet done
# R = 0.489 triplet done
# R = 0.514 singlet done
# R = 0.514 triplet done
# R = 0.538 singlet done
# R = 0.538 triplet done
# R = 0.562 singlet done
# R = 0.562 triplet done
# R = 0.586 singlet done
# R = 0.586 triplet done
# R = 0.610 singlet done
# R = 0.610 triplet done
# R = 0.634 singlet done
# R = 0.634 triplet done
# R = 0.658 singlet done
# R = 0.658 triplet done
# R = 0.682 singlet done
# R = 0.682 triplet done
# R = 0.707 singlet done
# R = 0.707 triplet done
# R = 0.731 singlet done
# R = 0.731 triplet done
# R = 0.755 singlet done
# R = 0.755 triplet done
# R = 0.779 singlet done
# R = 0.779 triplet done
# R = 0.803 singlet done
# R = 0.803 triplet done
# R = 0.827 singlet done
# R = 0.827 triplet done
# R = 0.851 singlet done
# R = 0.851 triplet done
# R = 0.875 singlet done
# R = 0.875 triplet done
# R = 0.899 singlet done
# R = 0.899 triplet done
# R = 0.924 singlet done
# R = 0.924 triplet done
# R = 0.948 singlet done
# R = 0.948 triplet done
# R = 0.972 singlet done
# R = 0.972 triplet done
# R = 0.996 singlet done
# R = 0.996 triplet done
# R = 1.020 singlet done
# R = 1.020 triplet done
# R = 1.044 singlet done
# R = 1.044 triplet done
# R = 1.068 singlet done
# R = 1.068 triplet done
# R = 1.092 singlet done
# R = 1.092 triplet done
# R = 1.117 singlet done
# R = 1.117 triplet done
# R = 1.141 singlet done
# R = 1.141 triplet done
# R = 1.165 singlet done
# R = 1.165 triplet done
# R = 1.189 singlet done
# R = 1.189 triplet done
# R = 1.213 singlet done
# R = 1.213 triplet done
# R = 1.237 singlet done
# R = 1.237 triplet done
# R = 1.261 singlet done
# R = 1.261 triplet done
# R = 1.285 singlet done
# R = 1.285 triplet done
# R = 1.310 singlet done
# R = 1.310 triplet done
# R = 1.334 singlet done
# R = 1.334 triplet done
# R = 1.358 singlet done
# R = 1.358 triplet done
# R = 1.382 singlet done
# R = 1.382 triplet done
# R = 1.406 singlet done
# R = 1.406 triplet done
# R = 1.430 singlet done
# R = 1.430 triplet done
# R = 1.454 singlet done
# R = 1.454 triplet done
# R = 1.478 singlet done
# R = 1.478 triplet done
# R = 1.503 singlet done
# R = 1.503 triplet done
# R = 1.527 singlet done
# R = 1.527 triplet done
# R = 1.551 singlet done
# R = 1.551 triplet done
# R = 1.575 singlet done
# R = 1.575 triplet done
# R = 1.599 singlet done
# R = 1.599 triplet done
# R = 1.623 singlet done
# R = 1.623 triplet done
# R = 1.647 singlet done
# R = 1.647 triplet done
# R = 1.671 singlet done
# R = 1.671 triplet done
# R = 1.695 singlet done
# R = 1.695 triplet done
# R = 1.720 singlet done
# R = 1.720 triplet done
# R = 1.744 singlet done
# R = 1.744 triplet done
# R = 1.768 singlet done
# R = 1.768 triplet done
# R = 1.792 singlet done
# R = 1.792 triplet done
# R = 1.816 singlet done
# R = 1.816 triplet done
# R = 1.840 singlet done
# R = 1.840 triplet done
# R = 1.864 singlet done
# R = 1.864 triplet done
# R = 1.888 singlet done
# R = 1.888 triplet done
# R = 1.913 singlet done
# R = 1.913 triplet done
# R = 1.937 singlet done
# R = 1.937 triplet done
# R = 1.961 singlet done
# R = 1.961 triplet done
# R = 1.985 singlet done
# R = 1.985 triplet done
# R = 2.009 singlet done
# R = 2.009 triplet done
# R = 2.033 singlet done
# R = 2.033 triplet done
# R = 2.057 singlet done
# R = 2.057 triplet done
# R = 2.081 singlet done
# R = 2.081 triplet done
# R = 2.106 singlet done
# R = 2.106 triplet done
# R = 2.130 singlet done
# R = 2.130 triplet done
# R = 2.154 singlet done
# R = 2.154 triplet done
# R = 2.178 singlet done
# R = 2.178 triplet done
# R = 2.202 singlet done
# R = 2.202 triplet done
# R = 2.226 singlet done
# R = 2.226 triplet done
# R = 2.250 singlet done
# R = 2.250 triplet done
# R = 2.274 singlet done
# R = 2.274 triplet done
# R = 2.298 singlet done
# R = 2.298 triplet done
# R = 2.323 singlet done
# R = 2.323 triplet done
# R = 2.347 singlet done
# R = 2.347 triplet done
# R = 2.371 singlet done
# R = 2.371 triplet done
# R = 2.395 singlet done
# R = 2.395 triplet done
# R = 2.419 singlet done
# R = 2.419 triplet done
# R = 2.443 singlet done
# R = 2.443 triplet done
# R = 2.467 singlet done
# R = 2.467 triplet done
# R = 2.491 singlet done
# R = 2.491 triplet done
# R = 2.516 singlet done
# R = 2.516 triplet done
# R = 2.540 singlet done
# R = 2.540 triplet done
# R = 2.564 singlet done
# R = 2.564 triplet done
# R = 2.588 singlet done
# R = 2.588 triplet done
# R = 2.612 singlet done
# R = 2.612 triplet done
# R = 2.636 singlet done
# R = 2.636 triplet done
# R = 2.660 singlet done
# R = 2.660 triplet done
# R = 2.684 singlet done
# R = 2.684 triplet done
# R = 2.709 singlet done
# R = 2.709 triplet done
# R = 2.733 singlet done
# R = 2.733 triplet done
# R = 2.757 singlet done
# R = 2.757 triplet done
# R = 2.781 singlet done
# R = 2.781 triplet done
# R = 2.805 singlet done
# R = 2.805 triplet done
# R = 2.829 singlet done
# R = 2.829 triplet done
# R = 2.853 singlet done
# R = 2.853 triplet done
# R = 2.877 singlet done
# R = 2.877 triplet done
# R = 2.902 singlet done
# R = 2.902 triplet done
# R = 2.926 singlet done
# R = 2.926 triplet done
# R = 2.950 singlet done
# R = 2.950 triplet done
# R = 2.974 singlet done
# R = 2.974 triplet done
# R = 2.998 singlet done
# R = 2.998 triplet done
# R = 3.022 singlet done
# R = 3.022 triplet done
# R = 3.046 singlet done
# R = 3.046 triplet done
# R = 3.070 singlet done
# R = 3.070 triplet done
# R = 3.094 singlet done
# R = 3.094 triplet done
# R = 3.119 singlet done
# R = 3.119 triplet done
# R = 3.143 singlet done
# R = 3.143 triplet done
# R = 3.167 singlet done
# R = 3.167 triplet done
# R = 3.191 singlet done
# R = 3.191 triplet done
# R = 3.215 singlet done
# R = 3.215 triplet done
# R = 3.239 singlet done
# R = 3.239 triplet done
# R = 3.263 singlet done
# R = 3.263 triplet done
# R = 3.287 singlet done
# R = 3.287 triplet done
# R = 3.312 singlet done
# R = 3.312 triplet done
# R = 3.336 singlet done
# R = 3.336 triplet done
# R = 3.360 singlet done
# R = 3.360 triplet done
# R = 3.384 singlet done
# R = 3.384 triplet done
# R = 3.408 singlet done
# R = 3.408 triplet done
# R = 3.432 singlet done
# R = 3.432 triplet done
# R = 3.456 singlet done
# R = 3.456 triplet done
# R = 3.480 singlet done
# R = 3.480 triplet done
# R = 3.505 singlet done
# R = 3.505 triplet done
# R = 3.529 singlet done
# R = 3.529 triplet done
# R = 3.553 singlet done
# R = 3.553 triplet done
# R = 3.577 singlet done
# R = 3.577 triplet done
# R = 3.601 singlet done
# R = 3.601 triplet done
# R = 3.625 singlet done
# R = 3.625 triplet done
# R = 3.649 singlet done
# R = 3.649 triplet done
# R = 3.673 singlet done
# R = 3.673 triplet done
# R = 3.697 singlet done
# R = 3.697 triplet done
# R = 3.722 singlet done
# R = 3.722 triplet done
# R = 3.746 singlet done
# R = 3.746 triplet done
# R = 3.770 singlet done
# R = 3.770 triplet done
# R = 3.794 singlet done
# R = 3.794 triplet done
# R = 3.818 singlet done
# R = 3.818 triplet done
# R = 3.842 singlet done
# R = 3.842 triplet done
# R = 3.866 singlet done
# R = 3.866 triplet done
# R = 3.890 singlet done
# R = 3.890 triplet done
# R = 3.915 singlet done
# R = 3.915 triplet done
# R = 3.939 singlet done
# R = 3.939 triplet done
# R = 3.963 singlet done
# R = 3.963 triplet done
# R = 3.987 singlet done
# R = 3.987 triplet done
# R = 4.011 singlet done
# R = 4.011 triplet done
# R = 4.035 singlet done
# R = 4.035 triplet done
# R = 4.059 singlet done
# R = 4.059 triplet done
# R = 4.083 singlet done
# R = 4.083 triplet done
# R = 4.108 singlet done
# R = 4.108 triplet done
# R = 4.132 singlet done
# R = 4.132 triplet done
# R = 4.156 singlet done
# R = 4.156 triplet done
# R = 4.180 singlet done
# R = 4.180 triplet done
# R = 4.204 singlet done
# R = 4.204 triplet done
# R = 4.228 singlet done
# R = 4.228 triplet done
# R = 4.252 singlet done
# R = 4.252 triplet done
# R = 4.276 singlet done
# R = 4.276 triplet done
# R = 4.301 singlet done
# R = 4.301 triplet done
# R = 4.325 singlet done
# R = 4.325 triplet done
# R = 4.349 singlet done
# R = 4.349 triplet done
# R = 4.373 singlet done
# R = 4.373 triplet done
# R = 4.397 singlet done
# R = 4.397 triplet done
# R = 4.421 singlet done
# R = 4.421 triplet done
# R = 4.445 singlet done
# R = 4.445 triplet done
# R = 4.469 singlet done
# R = 4.469 triplet done
# R = 4.493 singlet done
# R = 4.493 triplet done
# R = 4.518 singlet done
# R = 4.518 triplet done
# R = 4.542 singlet done
# R = 4.542 triplet done
# R = 4.566 singlet done
# R = 4.566 triplet done
# R = 4.590 singlet done
# R = 4.590 triplet done
# R = 4.614 singlet done
# R = 4.614 triplet done
# R = 4.638 singlet done
# R = 4.638 triplet done
# R = 4.662 singlet done
# R = 4.662 triplet done
# R = 4.686 singlet done
# R = 4.686 triplet done
# R = 4.711 singlet done
# R = 4.711 triplet done
# R = 4.735 singlet done
# R = 4.735 triplet done
# R = 4.759 singlet done
# R = 4.759 triplet done
# R = 4.783 singlet done
# R = 4.783 triplet done
# R = 4.807 singlet done
# R = 4.807 triplet done
# R = 4.831 singlet done
# R = 4.831 triplet done
# R = 4.855 singlet done
# R = 4.855 triplet done
# R = 4.879 singlet done
# R = 4.879 triplet done
# R = 4.904 singlet done
# R = 4.904 triplet done
# R = 4.928 singlet done
# R = 4.928 triplet done
# R = 4.952 singlet done
# R = 4.952 triplet done
# R = 4.976 singlet done
# R = 4.976 triplet done
# R = 5.000 singlet done
# R = 5.000 triplet done
# Done. Wrote h2_fci_singlet_triplet.csv

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv

filename = "h2_fci_singlet_triplet.csv"

R = []
singlets = []
triplets = []

with open(filename, "r") as f:
    reader = csv.reader(f)
    header = next(reader)

    ncols = len(header) - 1
    half = ncols // 2

    singlets = [[] for _ in range(half)]
    triplets = [[] for _ in range(half)]

    for row in reader:
        R.append(float(row[0]))

        for i in range(half):
            try:
                singlets[i].append(float(row[1 + i]))
            except:
                singlets[i].append(np.nan)

        for i in range(half):
            try:
                triplets[i].append(float(row[1 + half + i]))
            except:
                triplets[i].append(np.nan)

R = np.array(R)
singlets = [np.array(x) for x in singlets]
triplets = [np.array(x) for x in triplets]

plt.figure(figsize=(10, 7))

for i, e in enumerate(singlets):
    if i == 0:
        plt.plot(R, e, linewidth=2.5, label=f"Singlet {i}")
    else:
        plt.plot(R, e, label=f"Singlet {i}")

for i, e in enumerate(triplets):
    plt.plot(R, e, linestyle="--", label=f"Triplet {i}")

plt.xlabel("Bond Length (Å)")
plt.ylabel("Energy (Hartree)")
plt.title("H2 FCI Potential Energy Curves: Singlets and Triplets")
plt.legend(ncol=2, fontsize=9)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
